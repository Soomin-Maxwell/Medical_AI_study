# %% [markdown]
# <a href="https://colab.research.google.com/github/Soomin-Maxwell/Medical_AI_study/blob/main/OpenCV_Contours.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-8498e7ef-0166-4c07-bc54-ecde520bc5b5" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-8498e7ef-0166-4c07-bc54-ecde520bc5b5">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving Digit.png to Digit.png

# %% [markdown]
# - cv2.boundingRect(contour) : Contour 를 포함하는 사각형을 그림.
# - 사각형의 X,Y 좌표와 높이를 반환

# %%
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread("Digit.png")
image_gray = cv2.cvtColor(image,cv2.COLOR_BGR2GRAY)
ret, thresh = cv2.threshold(image_gray, 230, 255, 0)


plt.imshow(cv2.cvtColor(image_gray, cv2.COLOR_BGR2RGB))
plt.show()
