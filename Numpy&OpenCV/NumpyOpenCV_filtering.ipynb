# %% [markdown]
# <a href="https://colab.research.google.com/github/Soomin-Maxwell/Medical_AI_study/blob/main/OpenCV_filtering.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Smoothing
# 컨볼루션 계산
# - 이미지에 커널/ 윈도우 부르는 것을 적용을 하여 각각의 값들을 곱해주는 것을 이야기 한다.
# - 각 커널의 값에 이미지 픽셀의 같은 위치의 값을 곱하고, 가중치의 합만큼 나눈다.
#
# Kerner 종류
# - Basic Kernel : 가중치가 모두 같음.
# - Gaussian Kernel : 정규 분포 (normal distribution)을 따름. 즉, 중간으로 갈 수록 크고 외곽으로 갈 수록 값이 작음.

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-24f1f0aa-10d7-4257-b681-8f6d8b62296e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-24f1f0aa-10d7-4257-b681-8f6d8b62296e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving gray.jpeg to gray.jpeg

# %%
import cv2
import matplotlib.pyplot as plt
import numpy as np

image = cv2.imread("gray.jpeg", cv2.IMREAD_GRAYSCALE)
plt.imshow(image, cmap ='gray')
plt.show()

# %%
size = 5
kernel = np.ones((size, size), np.float32) / (size ** 2)
print(kernel)
# Out:
# [[0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]
#  [0.04 0.04 0.04 0.04 0.04]]

# %%
dst = cv2.filter2D(image, -1, kernel)
plt.imshow(dst, cmap='gray')
plt.show()

# %%
import numpy as np
import cv2 as cv
from matplotlib import pyplot as plt
img = cv.imread('3408.jpeg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

dst = cv2.blur(image, (4, 4))
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()

# %%
import cv2

image = cv2.imread('gray.jpeg')
plt.imshow(cv2.cvtColor(image, cv2.COLOR_BGR2RGB))
plt.show()

# kernel_size: 홀수
dst = cv2.GaussianBlur(image, (5, 5), 0)
plt.imshow(cv2.cvtColor(dst, cv2.COLOR_BGR2RGB))
plt.show()
